# %% [markdown]
# # Exercise 9-2: Build a softmax classifier for Otto Group Product
# kaggle.com/c/otto-group-product-classification-challenge/data

# %%
import torch
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
# %matplotlib inline

# %%
class OttoDataset(Dataset):
    def __init__(self, filename):
        class_map = {
            'Class_1': 1,
            'Class_2': 2,
            'Class_3': 3,
            'Class_4': 4,
            'Class_5': 5,
            'Class_6': 6,
            'Class_7': 7,
            'Class_8': 8,
            'Class_9': 9,
        }
        df = pd.read_csv(filename)
        df.target = df.target.map(class_map)
        self.x_data = df[['feat_1', 'feat_2', 'feat_3', 'feat_4', 'feat_5', 'feat_6', 'feat_7', 'feat_8', 'feat_9', 'feat_10', 'feat_11', 'feat_12', 'feat_13', 'feat_14', 'feat_15', 'feat_16', 'feat_17', 'feat_18', 'feat_19', 'feat_20', 'feat_21', 'feat_22', 'feat_23', 'feat_24', 'feat_25', 'feat_26', 'feat_27', 'feat_28', 'feat_29', 'feat_30', 'feat_31', 'feat_32', 'feat_33', 'feat_34', 'feat_35', 'feat_36', 'feat_37', 'feat_38', 'feat_39', 'feat_40', 'feat_41', 'feat_42', 'feat_43', 'feat_44', 'feat_45', 'feat_46', 'feat_47', 'feat_48', 'feat_49', 'feat_50', 'feat_51', 'feat_52', 'feat_53', 'feat_54', 'feat_55', 'feat_56', 'feat_57', 'feat_58', 'feat_59', 'feat_60', 'feat_61', 'feat_62', 'feat_63', 'feat_64', 'feat_65', 'feat_66', 'feat_67', 'feat_68', 'feat_69', 'feat_70', 'feat_71', 'feat_72', 'feat_73', 'feat_74', 'feat_75', 'feat_76', 'feat_77', 'feat_78', 'feat_79', 'feat_80', 'feat_81', 'feat_82', 'feat_83', 'feat_84', 'feat_85', 'feat_86', 'feat_87', 'feat_88', 'feat_89', 'feat_90', 'feat_91', 'feat_92', 'feat_93']]
        self.y_data = df[['target']]
    def __getitem__(self, index):
        return self.x_data.iloc[index], self.y_data.iloc[index] 
    def __len__(self):
        return self.x_data.shape[0]

# %%
# dataset size is 61878 = 2*3*10313
# epoch = 10313
# batch_size = 6
dataset = OttoDataset('./train.csv')
train_loader = DataLoader(dataset=dataset, batch_size=6, shuffle=True, num_workers=2)

# %% [markdown]
# # 1. Design Model

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super().__init__()

# %% [markdown]
# # map the `class` from string to number 1 to 9

# %%
df.target = df.target.map(class_map)

# %% [markdown]
# # See correlation between features

# %%
# Find correlation between feature. It is great features have no correlation
colormap = plt.cm.RdBu
plt.figure(figsize=(140,120))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
